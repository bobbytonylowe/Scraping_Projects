# %% [markdown]
# # __Find Specific Words On Web Pages With Scrapy__
#
# - Scrapy is a fast high-level web crawling and web scraping framework (in python), used to crawl websites and extract structured data from their pages.
# - It can be used for a wide range of purposes, from data mining to monitoring and automated testing. (see https://docs.scrapy.org/en/latest/)
#
# #### __Its uses:__
# - Scrapy can be used to find specific words on web pages and return the webpage url
# - It can be used to find specific information about products on multiple pages
#
# #### __In this example:__
# - Lets say we want to search flyertalk articles for some information on booking hotels by the phone
# - The following code will crawl through each webpage and return a URL link if the word "phone", "hotel", "reservation" and "booked" has been mentioned on a webpage
#
# ### _Running the code in Anaconda Prompt_
# - 1) scrapy startproject wordlist_scraper
# - 2) cd wordlist_scraper
# - 3) __scrapy crawl webcrawler > hotel_phone_project.csv__

# %%
import csv
from io import StringIO
from functools import partial
from scrapy.http import Request
from scrapy.spiders import BaseSpider
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor
from scrapy.item import Item
import logging
import scrapy
import re

def find_all_substrings(string, sub):

    import re
    starts = [match.start() for match in re.finditer(re.escape(sub), string)]
    return starts

class WebsiteSpider(CrawlSpider):

    name = "webcrawler" 
    allowed_domains = ["www.flyertalk.com"] ##### Change the website ########
    
    start_urls = ["https://www.flyertalk.com"] ##### Change the website #####
    
    rules = [Rule(LinkExtractor(), follow=True, callback="check_buzzwords")]
    
    crawl_count = 0
    words_found = 0                                 


        
    def check_buzzwords(self, response):

        self.__class__.crawl_count += 1

        crawl_count = self.__class__.crawl_count

        ##### Change the words  ##########
        wordlist = ["phone", "hotel",
            "reservation", "booked",
            ]


        url = response.url
        contenttype = response.headers.get("content-type", "").decode('utf-8').lower()
        data = response.body.decode('utf-8')

        for word in wordlist:
                substrings = find_all_substrings(data, word)
                for pos in substrings:
                        ok = False
                        if not ok:
                                self.__class__.words_found += 1
                                print(word + ";" + url + ";")
                
        return Item()

    def _requests_to_follow(self, response):
        if getattr(response, "encoding", None) != None:
                return CrawlSpider._requests_to_follow(self, response)
        else:
                return []

# %% [markdown]
# ### Run the above code
# - The above code will crawl the website flyertalk and return a website page when it contains the words in wordlist = ["phone", "hotel","reservation", "booked"]
# - The following code was intruppted for example purposes

# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
import pandas as pd

process = CrawlerProcess(settings={'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',})

process.crawl(WebsiteSpider)
process.start()
# Out:
# 2019-07-31 16:40:49 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: scrapybot)
# 2019-07-31 16:40:49 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1a  20 Nov 2018), cryptography 2.4.2, Platform Windows-10-10.0.17134-SP0
# 2019-07-31 16:40:49 [scrapy.crawler] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2019-07-31 16:40:49 [scrapy.extensions.telnet] INFO: Telnet Password: c6458e47474f4fa5
# 2019-07-31 16:40:49 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2019-07-31 16:40:49 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-07-31 16:40:49 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-07-31 16:40:49 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-07-31 16:40:49 [scrapy.core.engine] INFO: Spider opened
# 2019-07-31 16:40:49 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-07-31 16:40:49 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-07-31 16:40:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com> (referer: None)
# 2019-07-31 16:40:51 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.facebook.com': <GET https://www.facebook.com/flyertalkforums>
# 2019-07-31 16:40:51 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'twitter.com': <GET https://twitter.com/FlyerTalk>
# 2019-07-31 16:40:51 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.flyertalk.com#carousel-1> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2019-07-31 16:40:51 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.internetbrands.com': <GET http://www.internetbrands.com/ib/terms/travel?site=www.flyertalk.com>
# 2019-07-31 16:40:51 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.flyertalk.com/forum/flight_connect.php> from <GET https://www.flyertalk.com/flightconnect/>
# 2019-07-31 16:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/help/rules.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/omni-366/> from <GET https://www.flyertalk.com/forum/omni-366>
# phone;https://www.flyertalk.com;
# phone;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# hotel;https://www.flyertalk.com;
# phone;https://www.flyertalk.com/help/rules.php;
# hotel;https://www.flyertalk.com/help/rules.php;
# 2019-07-31 16:40:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/information-desk/1520497-start-here-how-use-information-desk.html> from <GET https://www.flyertalk.com/forum/information-desk/1520497-welcome-what-information-desk-forum.html>
# 2019-07-31 16:40:52 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'gallery.flyertalk.com': <GET http://gallery.flyertalk.com/gallery/>
# 2019-07-31 16:40:52 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'ad.doubleclick.net': <GET https://ad.doubleclick.net/jump/ft_hp;kw=top;sect=hp;tile=1;sz=728x90;ord=123456789>
# 2019-07-31 16:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/lounge_connect.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:52 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.frugaltravelguy.com': <GET http://www.frugaltravelguy.com>
# 2019-07-31 16:40:52 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.frequentflier.com': <GET http://www.frequentflier.com>
# 2019-07-31 16:40:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/destinations-704/> from <GET https://www.flyertalk.com/forum/destinations-704>
# 2019-07-31 16:40:52 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/lounge_connect.php> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 42918: invalid start byte
# 2019-07-31 16:40:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/travel-dining-161/> from <GET https://www.flyertalk.com/forum/travel-dining-161>
# 2019-07-31 16:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/subscription.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/miles-points-1/> from <GET https://www.flyertalk.com/forum/miles-points-1>
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/flight_connect.php> from <GET http://www.flyertalk.com/forum/flight_connect.php>
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/private.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/subscription.php> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64245: invalid start byte
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/usercp.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/airlines-mileage-programs-374/> from <GET https://www.flyertalk.com/forum/airlines-mileage-programs-374>
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/private.php> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64220: invalid start byte
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/usercp.php> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64215: invalid start byte
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/community-367/> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/flyertalk-cares-688/> from <GET http://www.flyertalk.com/forum/flyertalk-cares-688/>
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/legal-notices.php> from <GET http://www.flyertalk.com/legal-notices.php>
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/profile.php?do=editoptions> from <GET http://www.flyertalk.com/forum/profile.php?do=editoptions>
# 2019-07-31 16:40:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/profile.php?do=editprofilepic> from <GET http://www.flyertalk.com/forum/profile.php?do=editprofilepic>
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/community-367/> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 78892: invalid start byte
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/omni-366/> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/cdn-cgi/l/email-protection#acefc3c1c1d9c2c5d8d5e8c5dec9cfd8c3deeceac0d5c9def8cdc0c782cfc3c1> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/search.php> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/omni-366/> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 66004: invalid start byte
# 2019-07-31 16:40:53 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.cloudflare.com': <GET https://www.cloudflare.com/sign-up?utm_source=email_protection>
# 2019-07-31 16:40:53 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'support.cloudflare.com': <GET https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation->
# 2019-07-31 16:40:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/search.php> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 71329: invalid start byte
# 2019-07-31 16:40:53 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.flyertalk.com/%7B%7BoPost.post_permalink%7D%7D> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:53 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.flyertalk.com/%7B%7BoPost.post_permalink%7D%7D>: HTTP status code is not handled or not allowed
# 2019-07-31 16:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/information-desk/1520497-start-here-how-use-information-desk.html> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/flight_connect.php> (referer: None)
# 2019-07-31 16:40:54 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/information-desk/1520497-start-here-how-use-information-desk.html> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 90168: invalid start byte
# 2019-07-31 16:40:54 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/flight_connect.php> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 42927: invalid start byte
# 2019-07-31 16:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/support-services-385/> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:54 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/support-services-385/> (referer: https://www.flyertalk.com/help/rules.php)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 68208: invalid start byte
# 2019-07-31 16:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-lobby/> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/flyertalk-cares-688/> (referer: None)
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# hotel;https://www.flyertalk.com/the-lobby/;
# booked;https://www.flyertalk.com/the-lobby/;
# 2019-07-31 16:40:54 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/flyertalk-cares-688/> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x97 in position 62465: invalid start byte
# 2019-07-31 16:40:54 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (meta refresh) to <GET https://www.flyertalk.com/chat/chatlog.php> from <GET https://www.flyertalk.com/chat/>
# 2019-07-31 16:40:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://www.internetbrands.com/travel/advertise/> from <GET https://www.flyertalk.com/help/advertise.php>
# 2019-07-31 16:40:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/hotels-places-stay-389/> from <GET https://www.flyertalk.com/forum/hotels-loyalty-programs-389/>
# 2019-07-31 16:40:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/profile.php?do=editprofilepic> (referer: None)
# 2019-07-31 16:40:55 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/profile.php?do=editprofilepic> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64315: invalid start byte
# 2019-07-31 16:40:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/bookclub.php> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.flyertalk.com/forum/flyertalk-cares-688/> from <GET https://www.flyertalk.com/cares/>
# 2019-07-31 16:40:55 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.mileageprobook.com': <GET http://www.mileageprobook.com>
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/awards/;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# hotel;https://www.flyertalk.com/bookclub.php;
# 2019-07-31 16:40:55 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.amazon.com': <GET http://www.amazon.com/exec/obidos/ASIN/0385722370/webflyer-20>
# 2019-07-31 16:40:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.flyertalk.com/forum/premium_subscription.php> from <GET https://www.flyertalk.com/forum/claim_subscription.php>
# 2019-07-31 16:40:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.flyertalk.com/articles> from <GET https://www.flyertalk.com/story>
# 2019-07-31 16:40:55 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.flyertalk.com/articles/author/%7B%7B%20oPost.post_user_nicename%20%7D%7D> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.internetbrands.com/travel/advertise/> from <GET http://www.internetbrands.com/travel/advertise/>
# 2019-07-31 16:40:56 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.flyertalk.com/articles/author/%7B%7B%20oPost.post_user_nicename%20%7D%7D>: HTTP status code is not handled or not allowed
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/airlines-mileage-programs-374/> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/external.php?type=RSS2> from <GET http://www.flyertalk.com/forum/external.php?type=RSS2>
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/hotels-places-stay-389/> (referer: https://www.flyertalk.com)
# 2019-07-31 16:40:56 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/airlines-mileage-programs-374/> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf6 in position 70291: invalid start byte
# 2019-07-31 16:40:56 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/hotels-places-stay-389/> (referer: https://www.flyertalk.com)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 38248: invalid continuation byte
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/profile.php?do=editoptions> (referer: None)
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2012/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/premium_subscription.php> from <GET http://www.flyertalk.com/forum/premium_subscription.php>
# 2019-07-31 16:40:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/articles> from <GET http://www.flyertalk.com/articles>
# 2019-07-31 16:40:56 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/profile.php?do=editoptions> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64303: invalid start byte
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/extras/> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:56 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.kayak.com': <GET https://www.kayak.com/in?a=flyertalk&p=logo%2Fawards%2Fsite&url=%2Fh%2Fmlanding%2Ffd>
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2013/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2014/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:57 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'blogs.flyertalk.com': <GET http://blogs.flyertalk.com>
# 2019-07-31 16:40:57 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.webflyer.com': <GET http://www.webflyer.com/extras/postcards/>
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2012/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# hotel;https://www.flyertalk.com/awards/2013/;
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2015/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.flyertalk.com/forum/ftchat.php> from <GET https://www.flyertalk.com/chat/chatlog.php>
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2014/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# hotel;https://www.flyertalk.com/awards/2015/;
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-lobby/page/8> (referer: https://www.flyertalk.com/the-lobby/)
# 2019-07-31 16:40:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.internetbrands.com/travel/contact/> from <GET https://www.internetbrands.com/travel/advertise/>
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2016/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2017/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.flyertalk.com/articles/category/news> from <GET https://www.flyertalk.com/articles>
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2018/> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/townhall/> (referer: https://www.flyertalk.com/help/rules.php)
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/the-lobby/page/8;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2016/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# hotel;https://www.flyertalk.com/awards/2017/;
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/awards/2019/> (referer: https://www.flyertalk.com/awards/)
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2018/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# hotel;https://www.flyertalk.com/awards/2019/;
# 2019-07-31 16:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/acl/> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:40:59 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2019-07-31 16:40:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:40:59 [scrapy.core.engine] INFO: Closing spider (shutdown)
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.ksat.com': <GET https://www.ksat.com/news/monkey-on-the-loose-at-san-antonio-airport>
# 2019-07-31 16:40:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.internetbrands.com/travel/contact/> (referer: None)
# phone;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# phone;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# hotel;https://www.flyertalk.com/articles/monkey-named-dawkins-goes-on-two-hour-chase-at-sat.html;
# phone;https://www.internetbrands.com/travel/contact/;
# phone;https://www.internetbrands.com/travel/contact/;
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.fodors.com': <GET https://www.fodors.com>
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'wikitravel.org': <GET https://wikitravel.org/>
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.thehulltruth.com': <GET https://www.thehulltruth.com/>
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.offshoreonly.com': <GET https://www.offshoreonly.com/>
# 2019-07-31 16:40:59 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.rctech.net': <GET https://www.rctech.net/>
# ...
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 73877: invalid start byte
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# phone;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# hotel;https://www.flyertalk.com/articles/a-boeing-787-captain-gives-tip-on-how-to-survive-if-your-plane-goes-down.html;
# 2019-07-31 16:41:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/external.php?type=RSS2> (referer: None)
# 2019-07-31 16:41:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:41:02 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.flyertalk.com/forum/forumdisplay.php?f=605> from <GET http://www.flyertalk.com/forum/forumdisplay.php?f=605>
# 2019-07-31 16:41:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/external.php?type=RSS2> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 7892: invalid start byte
# 2019-07-31 16:41:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/ftchat.php> (referer: https://www.flyertalk.com/help/rules.php)
# 2019-07-31 16:41:02 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.thisisinsider.com': <GET http://www.thisisinsider.com/female-pilot-calls-out-sexist-male-passengers-twitter-2018-5>
# 2019-07-31 16:41:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.flyertalk.com/forum/ftchat.php> (referer: https://www.flyertalk.com/help/rules.php)
# Traceback (most recent call last):
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\robert.lowe\AppData\Local\Continuum\anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-00c1147cb19d>", line 47, in check_buzzwords
#     data = response.body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 64215: invalid start byte
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# phone;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# hotel;https://www.flyertalk.com/articles/pilot-takes-to-twitter-over-sexist-comments.html;
# 2019-07-31 16:41:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html> (referer: https://www.flyertalk.com/awards/)
# 2019-07-31 16:41:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-lobby/author/wendywilliams> (referer: https://www.flyertalk.com/the-lobby/page/8)
# 2019-07-31 16:41:03 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.businessinsider.in': <GET https://www.businessinsider.in/Chinas-social-credit-system-has-blocked-people-from-taking-11-million-flights-and-4-million-train-trips/articleshow/64255175.cms>
# 2019-07-31 16:41:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-gate/> (referer: https://www.flyertalk.com/help/rules.php)
# phone;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# phone;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/articles/chinese-social-credit-blocks-11-14-million-flights.html;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# hotel;https://www.flyertalk.com/the-lobby/author/wendywilliams;
# 2019-07-31 16:41:04 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'feeds.flyertalk.com': <GET http://feeds.flyertalk.com/flyertalk>
# 2019-07-31 16:41:04 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'thetransnationalpost.com': <GET http://thetransnationalpost.com/blog/2016/12/10/flying-rights-granted-to-subsidiary-of-norwegian-air-shuttle-but-what-exactly-does-that-mean/>
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# hotel;https://www.flyertalk.com/the-gate/;
# reservation;https://www.flyertalk.com/the-gate/;
# reservation;https://www.flyertalk.com/the-gate/;
# 2019-07-31 16:41:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/forum/premium_subscription.php> (referer: None)
# 2019-07-31 16:41:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-lobby/page/7> (referer: https://www.flyertalk.com/the-lobby/page/8)
# 2019-07-31 16:41:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.flyertalk.com/the-lobby/page/6> (referer: https://www.flyertalk.com/the-lobby/page/8)
# 2019-07-31 16:41:04 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 45492,
#  'downloader/request_count': 77,
#  'downloader/request_method_count/GET': 77,
#  'downloader/response_bytes': 777270,
#  'downloader/response_count': 77,
#  'downloader/response_status_count/200': 48,
#  'downloader/response_status_count/301': 24,
#  'downloader/response_status_count/302': 2,
#  'downloader/response_status_count/404': 3,
#  'dupefilter/filtered': 1429,
#  'finish_reason': 'shutdown',
#  'finish_time': datetime.datetime(2019, 7, 31, 15, 41, 4, 714051),
#  'httperror/response_ignored_count': 3,
#  'httperror/response_ignored_status_count/404': 3,
#  'log_count/DEBUG': 113,
#  'log_count/ERROR': 18,
#  'log_count/INFO': 13,
#  'offsite/domains': 35,
#  'offsite/filtered': 221,
#  'request_depth_max': 5,
#  'response_received_count': 50,
#  'scheduler/dequeued': 77,
#  'scheduler/dequeued/memory': 77,
#  'scheduler/enqueued': 307,
#  'scheduler/enqueued/memory': 307,
#  'spider_exceptions/UnicodeDecodeError': 18,
#  'start_time': datetime.datetime(2019, 7, 31, 15, 40, 49, 792017)}
# 2019-07-31 16:41:04 [scrapy.core.engine] INFO: Spider closed (shutdown)
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/7;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
# hotel;https://www.flyertalk.com/the-lobby/page/6;
